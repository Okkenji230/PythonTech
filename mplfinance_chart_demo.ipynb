# %% [markdown]
# # mplfinanceライブラリを用いた株価チャートの描画

# %%
import pandas as pd
from pandas_datareader import data as pdr
import mplfinance as fplt
import datetime
import yfinance as yf

# %% [markdown]
# ## 株価データの取得

# %%
start = "2023-4-1"
end = datetime.date.today()
ticker = "5334.T" # 9983:ファーストリテイリング
yf.pdr_override()
# yahooサイトからデータをダウンロード
df = pdr.get_data_yahoo(ticker, start, end)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High     Low   Close  Adj Close   Volume
# Date
# 2023-04-03  2736.0  2758.0  2727.0  2756.0     2756.0  1380000
# 2023-04-04  2746.0  2754.0  2735.0  2753.0     2753.0  1155900
# 2023-04-05  2725.0  2725.0  2680.0  2681.0     2681.0  1127300
# 2023-04-06  2657.0  2657.0  2628.0  2635.0     2635.0  1083300
# 2023-04-07  2645.0  2674.0  2643.0  2666.0     2666.0   776200

# %%
# 指定可能なtype: 'ohlc'(default), 'candle', 'line', 'renko', 'pnf'
fplt.plot(df,type='renko',figsize =(16,5), style='yahoo', 
          title = "STOCK PRICE CHART FOR {0}".format(ticker))
