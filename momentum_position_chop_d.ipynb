# %% [markdown]
# # モメンタム取引のためのオシレーター指標によるポジション判定 (Choppiness含む)

# %% [raw]
# 5 Great Indicators for Momentum Trading You May Not Know.
# https://medium.com/@kridtapon/5-great-indicators-for-momentum-trading-you-may-not-know-c7fa0664e84e

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import date, datetime, timedelta
import matplotlib.pyplot as plt
import talib
import warnings
import plotly.graph_objects as go
import mplfinance as mpf
import pickle
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ## ta-libにない関数の定義

# %%
# function Klinger Volume Oscillator (KVO)
def klinger_volume_oscillator(df, short_period=34, long_period=55, signal_period=13):
    df['High-Low'] = df['High'] - df['Low']
    df['High-Close'] = np.abs(df['High'] - df['Close'].shift(1))
    df['Low-Close'] = np.abs(df['Low'] - df['Close'].shift(1))
    df['TrueRange'] = df[['High-Low', 'High-Close', 'Low-Close']].max(axis=1)
    df['VolumeForce'] = np.where(df['Close'] > df['Close'].shift(1), df['Volume'], -df['Volume'])
    df['KVO'] = (df['VolumeForce'].rolling(window=short_period).sum() -
                 df['VolumeForce'].rolling(window=long_period).sum())
    df['KVO_Signal'] = df['KVO'].rolling(window=signal_period).mean()
    return df['KVO'], df['KVO_Signal']

# function Elder's Force Index (EFI)
def elder_force_index(df, period=2):
    df['EFI'] = (df['Close'] - df['Close'].shift(1)) * df['Volume']
    df['EFI_Smoothed'] = df['EFI'].rolling(window=period).mean()
    return df['EFI_Smoothed']

# function true_strength_index (TSI)
def true_strength_index(df, short_period=13, long_period=25):
    df['Change'] = df['Close'] - df['Close'].shift(1)
    df['Smoothed1'] = df['Change'].ewm(span=short_period, adjust=False).mean()
    df['Smoothed2'] = df['Smoothed1'].ewm(span=long_period, adjust=False).mean()
    df['AbsChange'] = abs(df['Change'])
    df['AbsSmoothed1'] = df['AbsChange'].ewm(span=short_period, adjust=False).mean()
    df['AbsSmoothed2'] = df['AbsSmoothed1'].ewm(span=long_period, adjust=False).mean()
    df['TSI'] = (df['Smoothed2'] / df['AbsSmoothed2']) * 100
    return df['TSI']

# オーサムオシレーター
def awesome_oscillator(df, wshort=5, wlong=34):
  # 中値
  df['med'] = (df['High']+df['Low']) / 2
  # オーサムオシレーター
  df['ao'] = df['med'].rolling(wshort).mean() - df['med'].rolling(wlong).mean()
  # 加速減速オシレーター
  df['ado'] = df['ao'] - df['ao'].rolling(wshort).mean()
  return df['ao'], df['ado']

# Choppiness Index
def choppiness_index(data, period=14):
    # Calculate the True Range
    high_low = data['High'] - data['Low']
    high_close = np.abs(data['High'] - data['Close'].shift(1))
    low_close = np.abs(data['Low'] - data['Close'].shift(1))
    true_range = pd.concat([high_low, high_close, low_close], axis=1).max(axis=1)
    # Sum of the True Range over the given period
    atr = true_range.rolling(window=period).sum()
    # Calculate the difference between the highest high and lowest low over the period
    max_high = data['High'].rolling(window=period).max()
    min_low = data['Low'].rolling(window=period).min()
    # Calculate the Choppiness Index
    chop = 100 * np.log10(atr / (max_high - min_low)) / np.log10(period)
    return chop

# %% [markdown]
# ## 銘柄リストの作成

# %%
# 銘柄コード辞書を読み込む
with open('JPX_code_dict.pickle', mode='rb') as f:
    jpx = pickle.load(f)

# %%
# チェック対象銘柄リストを読み込む
df01 = pd.read_excel('personal_invest.xlsx')
df02 = pd.read_excel('popular_invest.xlsx')
df1 = pd.concat([df01, df02], axis=0)

# %%
# 米国チェック対象銘柄リストを読み込む
df04 = pd.read_excel('personal_invest_us.xlsx')
df2 = df04[df04['flag'] == 1]
df2.tail()
# Out:
#        category             name code  flag     source
# 36        軍需・宇宙         RTX Corp  RTX   1.0  みんかぶ人気テーマ
# 37        軍需・宇宙  ハネウェル・インターナショナル  HON   1.0  みんかぶ人気テーマ
# 38  原子力・航空機エンジン        GEエアロスペース   GE   1.0  みんかぶ人気テーマ
# 39      総合エネルギー            シェブロン  CVX   1.0    DMM人気銘柄
# 40       特殊化学製品           アルベマール  ALB   1.0    DMM人気銘柄

# %%
# 米国銘柄リストより仮辞書を作成して日本の辞書に結合する
df2.loc[:,'description'] = df2.copy().loc[:,'name'] + '：' + df2.copy().loc[:,'category']
df3 = df2.set_index('code')
usadd = df3.to_dict()['description']
jpx.update(usadd)
# Out:
# C:\Users\nicjp\AppData\Local\Temp\ipykernel_12504\510649325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:,'description'] = df2.copy().loc[:,'name'] + '：' + df2.copy().loc[:,'category']

# %%
# コード番号からTickerリストを作成
df1['ticker'] = df1['code'].astype(str)+'.T'
list_ticker = df1['ticker'].tolist() + df2['code'].tolist()
print(list_ticker)
# Out:
# ['9531.T', '9432.T', '7419.T', '8267.T', '2730.T', '2340.T', '9726.T', '9020.T', '8411.T', '4182.T', '8593.T', '2317.T', '4042.T', '8801.T', '8089.T', '9006.T', '6742.T', '2503.T', '7186.T', '7201.T', '8131.T', '5411.T', '4004.T', '2432.T', '6632.T', '2002.T', '5991.T', '1963.T', '7011.T', '7013.T', '2201.T', '2440.T', '1942.T', '6617.T', '6361.T', '5471.T', '9507.T', '9502.T', '9503.T', '9508.T', '9506.T', '9504.T', '1605.T', '2502.T', '2914.T', '3038.T', '3382.T', '4005.T', '4385.T', '4503.T', '4689.T', '4755.T', '5020.T', '5803.T', '6178.T', '6315.T', '6323.T', '6501.T', '6503.T', '6526.T', '6594.T', '6702.T', '6723.T', '6752.T', '6758.T', '6762.T', '6902.T', '6971.T', '7003.T', '7012.T', '7182.T', '7203.T', '7211.T', '7261.T', '7267.T', '7269.T', '7272.T', '7733.T', '8031.T', '8058.T', '8306.T', '8308.T', '8316.T', '8410.T', '8601.T', '8604.T', '8725.T', '8766.T', '8801.T', '9101.T', '9104.T', '9107.T', '9434.T', 'CHD', 'COST', 'HD', 'LMT', 'MKC', 'NKE', 'V', 'DUK', 'NEE', 'SO', 'JNJ', 'PG', 'ROL', 'UNP', 'ENTG', 'ETN', 'AAPL', 'AMZN', 'GOOGL', 'ISRG', 'META', 'MSFT', 'NFLX', 'NVDA', 'ORCL', 'TSLA', 'ARM', 'INTC', 'KO', 'SBUX', 'TSM', 'AQN', 'MO', 'OKE', 'VZ', 'RTX', 'HON', 'GE', 'CVX', 'ALB']

# %% [markdown]
# ## データの読み込みとシグナル判定

# %%
# 期間の指定
end_date = datetime.today()
start_date = end_date - timedelta(days=730)

# %%
# 各銘柄についてシグナル判定を行い結果を縦連結する
df0 = pd.DataFrame()
for symbol in list_ticker:
    # yahooサイトからデータをダウンロード
    data = yf.download(symbol, start_date, end_date)
    data.columns = [col[0] if isinstance(col, tuple) else col for col in data.columns]
    data['ticker'] = symbol
    df = data.reset_index()
    # 指標値の計算
    df['SMA_short'] = talib.SMA(df['Close'], timeperiod=5)
    df['SMA_long'] = talib.SMA(df['Close'], timeperiod=25)
    df['CMO'] = talib.CMO(df['Close'], timeperiod=14)
    df['KVO'], df['KVO_Signal'] = klinger_volume_oscillator(df)
    df['EFI'] = elder_force_index(df)
    df['TSI'] = true_strength_index(df)
    df['ARO'] = talib.AROONOSC(df['High'], df['Low'], timeperiod=25)
    df['MACD'], df['MACD_signal'], df['MACD_hist'] = talib.MACD(df['Close'], \
            fastperiod=12, slowperiod=26, signalperiod=9)
    df['AO'], df['ADO'] = awesome_oscillator(df)
    df['TRIX'] = talib.TRIX(df['Close'], timeperiod=9)
    df['CHOP'] = choppiness_index(df)
    # ポジションの判定
    df['SMA_buy'] = (df['SMA_short'] > df['SMA_long'])
    df['SMA_sell'] = (df['SMA_short'] < df['SMA_long'])
    df['CMO_buy'] = (df['CMO'] > 0)
    df['CMO_sell'] = (df['CMO'] < 0)
    df['KVO_buy'] = (df['KVO'] > 0)
    df['KVO_sell'] = (df['KVO'] < 0)
    df['EFI_buy'] = (df['EFI'] > 0)
    df['EFI_sell'] = (df['EFI'] < 0)
    df['TSI_buy'] = (df['TSI'] > 0)
    df['TSI_sell'] = (df['TSI'] < 0)
    df['ARO_buy'] = (df['ARO'] > 0)
    df['ARO_sell'] = (df['ARO'] < 0)
    df['MACD_buy'] = (df['MACD'] > df['MACD_signal'])
    df['MACD_sell'] = (df['MACD'] < df['MACD_signal'])
    df['AO_buy'] = (df['AO'] > 0)
    df['AO_sell'] = (df['AO'] < 0)
    df['TRIX_buy'] = (df['TRIX'] > 0)
    df['TRIX_sell'] = (df['TRIX'] < 0)
    df['CHOP_range'] = (df['CHOP'] > 61.8)
    df['CHOP_trend'] = (df['CHOP'] < 38.2)
    # 一銘柄のシグナル判定結果の最終行のみを元のデータに縦連結する
    df0 = pd.concat([df0,df.tail(1)],axis=0)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## 結果の整理と表示

# %%
# コードから銘柄名を返す関数
def ticker_dict(df):
    return jpx.get(df)

# %%
# 銘柄名の付与
# 後で参照するためreset_index()によるインデックスのふり直しは必要
df_signal = df0.loc[:,['Date','ticker','Close',\
                       'SMA_buy','SMA_sell',\
                       'CMO_buy','CMO_sell','KVO_buy','KVO_sell',\
                       'EFI_buy','EFI_sell','TSI_buy','TSI_sell',\
                       'ARO_buy','ARO_sell','MACD_buy','MACD_sell',\
                       'AO_buy','AO_sell','TRIX_buy','TRIX_sell',\
                       'CHOP_range','CHOP_trend']].reset_index()
df_signal['ticker2'] = df_signal['ticker'].mask(df_signal['ticker'].str.endswith('.T'),df_signal['ticker'].str[:-2])
df_signal['cname'] = df_signal['ticker2'].map(ticker_dict)
df_signal.head()
# Out:
#    index       Date  ticker        Close  SMA_buy  SMA_sell  CMO_buy  \
# 0    490 2025-01-29  9531.T  4052.000000    False      True    False
# 1    490 2025-01-29  9432.T   153.199997    False      True    False
# 2    490 2025-01-29  7419.T  2205.000000    False      True     True
# 3    490 2025-01-29  8267.T  3722.000000     True     False     True
# 4    490 2025-01-29  2730.T  1820.000000     True     False     True
#
#    CMO_sell  KVO_buy  KVO_sell  ...  MACD_buy  MACD_sell  AO_buy  AO_sell  \
# 0      True    False      True  ...     False       True   False     True
# 1      True    False      True  ...      True      False   False     True
# 2     False    False      True  ...      True      False   False     True
# 3     False     True     False  ...      True      False   False     True
# 4     False    False      True  ...      True      False    True    False
#
#    TRIX_buy  TRIX_sell  CHOP_range  CHOP_trend  ticker2   cname
# 0     False       True       False       False     9531    東京瓦斯
# 1     False       True       False       False     9432  日本電信電話
# 2     False       True       False       False     7419     ノジマ
# 3      True      False       False       False     8267     イオン
# 4      True      False       False       False     2730   エディオン
#
# [5 rows x 26 columns]

# %%
# シグナルメッセージの付与
df_signal["signal_str"] = np.nan
df_signal["signal_total"] = np.nan
for irow in range(len(df_signal)):
    str_signal = ''
    total_signal = 0
    if df_signal.SMA_buy[irow]:
        str_signal += 'SMA+,'
        total_signal += 100
    if df_signal.SMA_sell[irow]:
        str_signal += 'SMA-,'
        total_signal -= 100
    if df_signal.CMO_buy[irow]:
        str_signal += 'CMO+,'
        total_signal += 100
    if df_signal.CMO_sell[irow]:
        str_signal += 'CMO-,'
        total_signal -= 100
    if df_signal.KVO_buy[irow]:
        str_signal += 'KVO+,'
        total_signal += 100
    if df_signal.KVO_sell[irow]:
        str_signal += 'KVO-,'
        total_signal -= 100
    if df_signal.EFI_buy[irow]:
        str_signal += 'EFI+,'
        total_signal += 100
    if df_signal.EFI_sell[irow]:
        str_signal += 'EFI-,'
        total_signal -= 100
    if df_signal.TSI_buy[irow]:
        str_signal += 'TSI+,'
        total_signal += 100
    if df_signal.TSI_sell[irow]:
        str_signal += 'TSI-,'
        total_signal -= 100
    if df_signal.ARO_buy[irow]:
        str_signal += 'ARO+,'
        total_signal += 100
    if df_signal.ARO_sell[irow]:
        str_signal += 'ARO-,'
        total_signal -= 100
    if df_signal.MACD_buy[irow]:
        str_signal += 'MACD+,'
        total_signal += 100
    if df_signal.MACD_sell[irow]:
        str_signal += 'MACD-,'
        total_signal -= 100
    if df_signal.AO_buy[irow]:
        str_signal += 'AO+,'
        total_signal += 100
    if df_signal.AO_sell[irow]:
        str_signal += 'AO-,'
        total_signal -= 100
    if df_signal.TRIX_buy[irow]:
        str_signal += 'TRIX+,'
        total_signal += 100
    if df_signal.TRIX_sell[irow]:
        str_signal += 'TRIX-,'
        total_signal -= 100
    if df_signal.CHOP_range[irow]:
        str_signal += 'CHOPr,'
    if df_signal.CHOP_trend[irow]:
        str_signal += 'CHOPt,'
        total_signal *= 10
    df_signal.loc[irow,"signal_str"] = str_signal
    df_signal.loc[irow,"signal_total"] = total_signal

# %% [raw]
# CMO: Chande Momentum Oscillatorは最近の利益と損失を比較してモメンタムを測定します。従来のオシレーターとは異なり、上昇と下降の両方の動きを 1 回の計算に組み込みます。これにより、トレーダーはモメンタムの強さをバランスよく把握できます。
# KVO: Klinger Oscillatorはボリューム フローに焦点を当てて長期的なトレンドを検出すると同時に、短期的なモメンタムの変化も特定します。価格変動とボリュームを組み込むことで、トレンドの強さに関する洞察を提供します。
# EFI: Elder's Force Indexは価格の変化と取引量を組み合わせて、市場の動きの背後にある力を測定し、強いトレンドの始まりを特定するのに特に効果的です。
# TSI: True Strength Indexは市場のノイズを除去してより明確なシグナルを提供する、二重平滑化モメンタム オシレーターです。トレンドのある市場では特に役立ちます。
# ARO: アルーン・オシレーター（Aroon Oscillator） は、テクニカル分析においてトレンドの強さや方向性を評価するために使用されるモメンタム系の指標です。「アルーン」という名前は、サンスクリット語で「夜明け」や「新しい始まり」を意味し、新しいトレンドの始まりを見つけることを目的としています。
# MACD: トレンドの強さや方向性を測るのに優れた指標で、多くのトレーダーに利用されています。特に、トレンドフォロー戦略や転換点を狙う戦略において効果的です。より信頼性の高い分析を行うためには、他の指標（RSIやボリンジャーバンドなど）と組み合わせて使うのが推奨されます。
# AO: オーサム・オシレーター（Awesome Oscillator, AO） は、トレンドの勢いや市場のモメンタムを視覚化し、トレンド転換の兆候を見つけるために使用されるテクニカル指標です。この指標は、ビル・ウィリアムズによって開発され、短期モメンタムと長期モメンタムの違いを比較することで、市場の方向性を分析します。
# TRIX: TRIXオシレーター（Triple Exponential Average Oscillator）は、トレンドの方向性やモメンタムを測定するためのテクニカル指標です。3重指数移動平均（Triple Exponential Moving Average, TEMA）の変化率を基にしており、トレンドの方向性や転換点を捉えるために使用されます。主にスムーズな動きを提供することで、市場のノイズを取り除き、トレーダーに重要なシグナルを提供します。

# %%
# シグナル一覧の表示
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
df_tmp = df_signal[['Date', 'ticker', 'cname', 'signal_str', 'signal_total']]
df_table = df_tmp.sort_values(by='signal_total',ascending=False)
df_table
# Out:
#           Date  ticker                          cname  \
# 88  2025-01-29  8801.T                          三井不動産
# 13  2025-01-29  8801.T                          三井不動産
# 50  2025-01-29  4689.T                        ＬＩＮＥヤフー
# 122 2025-01-28    SBUX                     スターバックス：飲食
# 128 2025-01-28     RTX                 RTX Corp：軍需・宇宙
# 43  2025-01-29  2502.T                アサヒグループホールディングス
# 106 2025-01-28     UNP                  ユニオンパシフィック：鉄道
# 85  2025-01-29  8604.T                     野村ホールディングス
# 95  2025-01-28      HD                  ホームデポ：ホームセンター
# 48  2025-01-29  4385.T                           メルカリ
# 54  2025-01-29  6178.T                           日本郵政
# 105 2025-01-28     ROL                     ローリンズ：害虫駆除
# 130 2025-01-28      GE          GEエアロスペース：原子力・航空機エンジン
# 99  2025-01-28       V                       ビザ：クレジット
# 5   2025-01-29  2340.T                    極楽湯ホールディングス
# 15  2025-01-29  9006.T                         京浜急行電鉄
# 115 2025-01-28    NFLX                  ネットフリックス：動画配信
# 6   2025-01-29  9726.T                 ＫＮＴ－ＣＴホールディングス
# 61  2025-01-29  6702.T                            富士通
# 103 2025-01-28     JNJ            ジョンソンエンドジョンソン：生活必需品
# 131 2025-01-28     CVX                  シェブロン：総合エネルギー
# 100 2025-01-28     DUK                        デューク：電力
# 10  2025-01-29  8593.T                      三菱ＨＣキャピタル
# 84  2025-01-29  8601.T                     大和証券グループ本社
# 51  2025-01-29  4755.T                         楽天グループ
# 35  2025-01-29  5471.T                          大同特殊鋼
# 56  2025-01-29  6323.T                           ローツェ
# 62  2025-01-29  6723.T                   ルネサスエレクトロニクス
# 113 2025-01-28    META       メタ・プラットフォームズ：マグニフィセントセブン
# 102 2025-01-28      SO                         サザン：電力
# 55  2025-01-29  6315.T                           ＴＯＷＡ
# 93  2025-01-28     CHD                チャーチアンドホワイト：日用品
# 64  2025-01-29  6758.T                        ソニーグループ
# 92  2025-01-29  9434.T                         ソフトバンク
# 70  2025-01-29  7182.T                         ゆうちょ銀行
# 80  2025-01-29  8306.T              三菱ＵＦＪフィナンシャル・グループ
# 82  2025-01-29  8316.T                三井住友フィナンシャルグループ
# 110 2025-01-28    AMZN        アマゾン・ドット・コム：マグニフィセントセブン
# 121 2025-01-28      KO                      コカ・コーラ：飲食
# 67  2025-01-29  6971.T                            京セラ
# 66  2025-01-29  6902.T                           デンソー
# 24  2025-01-29  6632.T                       ＪＶＣケンウッド
# 4   2025-01-29  2730.T                          エディオン
# 21  2025-01-29  5411.T                    ＪＦＥホールディングス
# 29  2025-01-29  7013.T                            ＩＨＩ
# 31  2025-01-29  2440.T                           ぐるなび
# 8   2025-01-29  8411.T                 みずほフィナンシャルグループ
# 74  2025-01-29  7267.T                         本田技研工業
# 75  2025-01-29  7269.T                            スズキ
# 26  2025-01-29  5991.T                           日本発條
# 119 2025-01-28     ARM               アーム・ホールディングス：半導体
# 111 2025-01-28   GOOGL            アルファベット：マグニフィセントセブン
# 112 2025-01-28    ISRG        インテュイティヴ・サージカル：手術支援ロボット
# 27  2025-01-29  1963.T                     日揮ホールディングス
# 20  2025-01-29  8131.T              ミツウロコグループホールディングス
# 34  2025-01-29  6361.T                          荏原製作所
# 28  2025-01-29  7011.T                          三菱重工業
# 73  2025-01-29  7261.T                            マツダ
# 114 2025-01-28    MSFT            マイクロソフト：マグニフィセントセブン
# 45  2025-01-29  3038.T                           神戸物産
# 94  2025-01-28    COST                 コストコホールセール：小売り
# 3   2025-01-29  8267.T                            イオン
# 120 2025-01-28    INTC                       インテル：半導体
# 127 2025-01-28      VZ             ベライゾンコミュニケーションズ：通信
# 7   2025-01-29  9020.T                        東日本旅客鉄道
# 77  2025-01-29  7733.T                          オリンパス
# 117 2025-01-28    ORCL                    オラクル：データベース
# 18  2025-01-29  7186.T            コンコルディア・フィナンシャルグループ
# 71  2025-01-29  7203.T                         トヨタ自動車
# 96  2025-01-28     LMT                 ロッキードマーティン：軍用機
# 97  2025-01-28     MKC                      マコーミック：食品
# 123 2025-01-28     TSM  タイワン・セミコンダクター・マニュファクチャリング：半導体
# 98  2025-01-28     NKE                     ナイキ：スポーツ用品
# 65  2025-01-29  6762.T                            ＴＤＫ
# 9   2025-01-29  4182.T                         三菱瓦斯化学
# 126 2025-01-28     OKE                    ワンオーク：エネルギー
# 104 2025-01-28      PG            プロクターアンドギャンブル：生活必需品
# 53  2025-01-29  5803.T                           フジクラ
# 37  2025-01-29  9502.T                           中部電力
# 49  2025-01-29  4503.T                        アステラス製薬
# 124 2025-01-28     AQN  アルゴンキンパワーアンドユーティリティーズ：電力(カナダ)
# 11  2025-01-29  2317.T                           システナ
# 23  2025-01-29  2432.T                      ディー・エヌ・エー
# 101 2025-01-28     NEE                      ネクストエラ：電力
# 2   2025-01-29  7419.T                            ノジマ
# 58  2025-01-29  6503.T                           三菱電機
# 30  2025-01-29  2201.T                           森永製菓
# 44  2025-01-29  2914.T                        日本たばこ産業
# 38  2025-01-29  9503.T                           関西電力
# 33  2025-01-29  6617.T                           東光高岳
# 69  2025-01-29  7012.T                          川崎重工業
# 125 2025-01-28      MO                  アルトリアグループ：タバコ
# 46  2025-01-29  3382.T                セブン＆アイ・ホールディングス
# 83  2025-01-29  8410.T                          セブン銀行
# 39  2025-01-29  9508.T                           九州電力
# 47  2025-01-29  4005.T                           住友化学
# 109 2025-01-28    AAPL               アップル：マグニフィセントセブン
# 107 2025-01-28    ENTG                 インテグリス：半導体向け材料
# 129 2025-01-28     HON          ハネウェル・インターナショナル：軍需・宇宙
# 32  2025-01-29  1942.T                            関電工
# 60  2025-01-29  6594.T                           ニデック
# 86  2025-01-29  8725.T      ＭＳ＆ＡＤインシュアランスグループホールディングス
# 1   2025-01-29  9432.T                         日本電信電話
# 12  2025-01-29  4042.T                            東ソー
# 68  2025-01-29  7003.T                          三井Ｅ＆Ｓ
# 72  2025-01-29  7211.T                        三菱自動車工業
# 16  2025-01-29  6742.T                          京三製作所
# 76  2025-01-29  7272.T                         ヤマハ発動機
# 17  2025-01-29  2503.T                    キリンホールディングス
# 40  2025-01-29  9506.T                           東北電力
# 79  2025-01-29  8058.T                           三菱商事
# 81  2025-01-29  8308.T                    りそなホールディングス
# 19  2025-01-29  7201.T                          日産自動車
# 25  2025-01-29  2002.T                     日清製粉グループ本社
# 41  2025-01-29  9504.T                           中国電力
# 118 2025-01-28    TSLA                テスラ：マグニフィセントセブン
# 132 2025-01-28     ALB                  アルベマール：特殊化学製品
# 52  2025-01-29  5020.T                  ＥＮＥＯＳホールディングス
# 42  2025-01-29  1605.T                          ＩＮＰＥＸ
# 36  2025-01-29  9507.T                           四国電力
# 116 2025-01-28    NVDA             エヌビディア：マグニフィセントセブン
# 87  2025-01-29  8766.T                   東京海上ホールディングス
# 78  2025-01-29  8031.T                           三井物産
# 63  2025-01-29  6752.T                パナソニック　ホールディングス
# 59  2025-01-29  6526.T                        ソシオネクスト
# 57  2025-01-29  6501.T                          日立製作所
# 22  2025-01-29  4004.T                 レゾナック・ホールディングス
# 0   2025-01-29  9531.T                           東京瓦斯
# 108 2025-01-28     ETN      イートン・コーポレーション：自動車部品や無停電電源
# 91  2025-01-29  9107.T                           川崎汽船
# 90  2025-01-29  9104.T                           商船三井
# 89  2025-01-29  9101.T                           日本郵船
# 14  2025-01-29  8089.T                            ナイス
#
#                                                signal_str  signal_total
# 88   SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        9000.0
# 13   SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        9000.0
# 50   SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        9000.0
# 122  SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        9000.0
# 128  SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        9000.0
# 43   SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        9000.0
# 106  SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        9000.0
# 85   SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 95   SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 48   SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 54   SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 105  SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 130  SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 99   SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 5    SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 15   SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        7000.0
# 115  SMA+,CMO+,KVO-,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,CHOPt,        5000.0
# 6    SMA+,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,CHOPt,        1000.0
# 61         SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 103        SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 131        SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 100        SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 10         SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 84         SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 51         SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 35         SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 56         SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 62         SMA+,CMO+,KVO+,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         900.0
# 113        SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 102        SMA+,CMO+,KVO+,EFI+,TSI-,ARO+,MACD+,AO+,TRIX+,         700.0
# 55         SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 93         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 64         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 92         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 70         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 80         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 82         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 110        SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 121        SMA+,CMO+,KVO+,EFI+,TSI-,ARO+,MACD+,AO+,TRIX+,         700.0
# 67         SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 66         SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 24         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 4          SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 21         SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 29         SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 31         SMA+,CMO+,KVO+,EFI+,TSI-,ARO+,MACD+,AO+,TRIX+,         700.0
# 8          SMA+,CMO+,KVO-,EFI+,TSI+,ARO+,MACD+,AO+,TRIX+,         700.0
# 74         SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD-,AO+,TRIX+,         500.0
# 75         SMA+,CMO+,KVO-,EFI+,TSI+,ARO-,MACD+,AO+,TRIX+,         500.0
# 26         SMA+,CMO+,KVO-,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         500.0
# 119        SMA+,CMO+,KVO-,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         500.0
# 111        SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD-,AO+,TRIX+,         500.0
# 112        SMA+,CMO+,KVO-,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         500.0
# 27         SMA+,CMO-,KVO+,EFI-,TSI+,ARO+,MACD+,AO+,TRIX+,         500.0
# 20         SMA+,CMO+,KVO+,EFI-,TSI+,ARO-,MACD+,AO+,TRIX+,         500.0
# 34         SMA+,CMO-,KVO+,EFI-,TSI+,ARO+,MACD-,AO+,TRIX+,         300.0
# 28         SMA+,CMO+,KVO+,EFI-,TSI-,ARO+,MACD+,AO+,TRIX-,         300.0
# 73         SMA+,CMO+,KVO+,EFI-,TSI+,ARO+,MACD-,AO+,TRIX-,         300.0
# 114        SMA+,CMO+,KVO-,EFI-,TSI+,ARO-,MACD+,AO+,TRIX+,         300.0
# 45         SMA+,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO+,TRIX+,         300.0
# 94         SMA+,CMO+,KVO-,EFI+,TSI+,ARO-,MACD+,AO-,TRIX+,         300.0
# 3          SMA+,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX+,         300.0
# 120        SMA+,CMO-,KVO+,EFI-,TSI-,ARO+,MACD+,AO+,TRIX+,         300.0
# 127        SMA+,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,         100.0
# 7          SMA+,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,         100.0
# 77         SMA+,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,         100.0
# 117        SMA+,CMO-,KVO-,EFI-,TSI-,ARO+,MACD+,AO+,TRIX+,         100.0
# 18   SMA+,CMO+,KVO-,EFI+,TSI-,ARO+,MACD+,AO-,TRIX-,CHOPr,         100.0
# 71         SMA-,CMO+,KVO-,EFI+,TSI+,ARO+,MACD-,AO+,TRIX-,         100.0
# 96         SMA+,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO+,TRIX+,         100.0
# 97         SMA+,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,         100.0
# 123        SMA+,CMO-,KVO-,EFI-,TSI+,ARO-,MACD-,AO+,TRIX+,        -100.0
# 98         SMA+,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -100.0
# 65         SMA-,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -100.0
# 9          SMA+,CMO-,KVO-,EFI-,TSI-,ARO+,MACD-,AO+,TRIX+,        -100.0
# 126        SMA+,CMO-,KVO-,EFI-,TSI-,ARO+,MACD-,AO+,TRIX+,        -100.0
# 104        SMA+,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -100.0
# 53         SMA+,CMO-,KVO-,EFI-,TSI+,ARO-,MACD-,AO+,TRIX+,        -100.0
# 37         SMA-,CMO-,KVO+,EFI-,TSI-,ARO+,MACD+,AO+,TRIX-,        -100.0
# 49         SMA-,CMO+,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -100.0
# 124        SMA+,CMO-,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -100.0
# 11         SMA-,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -300.0
# 23         SMA-,CMO+,KVO-,EFI-,TSI+,ARO-,MACD-,AO+,TRIX-,        -300.0
# 101        SMA+,CMO-,KVO-,EFI-,TSI-,ARO+,MACD+,AO-,TRIX-,        -300.0
# 2          SMA-,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -300.0
# 58         SMA+,CMO-,KVO-,EFI-,TSI-,ARO+,MACD-,AO+,TRIX-,        -300.0
# 30         SMA-,CMO-,KVO+,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -300.0
# 44         SMA-,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -300.0
# 38   SMA-,CMO-,KVO+,EFI-,TSI-,ARO+,MACD+,AO-,TRIX-,CHOPr,        -300.0
# 33         SMA-,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -300.0
# 69         SMA-,CMO-,KVO-,EFI-,TSI+,ARO+,MACD-,AO+,TRIX-,        -300.0
# 125        SMA-,CMO+,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -300.0
# 46              SMA-,CMO-,KVO-,EFI+,TSI-,MACD+,AO-,TRIX-,        -400.0
# 83         SMA-,CMO-,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 39         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 47         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 109        SMA-,CMO+,KVO-,EFI+,TSI-,ARO-,MACD-,AO-,TRIX-,        -500.0
# 107        SMA+,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX+,        -500.0
# 129        SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 32         SMA-,CMO-,KVO-,EFI-,TSI+,ARO-,MACD-,AO+,TRIX-,        -500.0
# 60         SMA-,CMO-,KVO+,EFI-,TSI-,ARO+,MACD-,AO-,TRIX-,        -500.0
# 86         SMA-,CMO-,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 1          SMA-,CMO-,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 12         SMA-,CMO+,KVO-,EFI-,TSI-,ARO+,MACD-,AO-,TRIX-,        -500.0
# 68         SMA-,CMO+,KVO-,EFI+,TSI-,ARO-,MACD-,AO-,TRIX-,        -500.0
# 72         SMA-,CMO-,KVO+,EFI+,TSI-,ARO-,MACD-,AO-,TRIX-,        -500.0
# 16         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 76         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 17         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 40         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 79   SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,CHOPr,        -500.0
# 81   SMA-,CMO-,KVO-,EFI+,TSI-,ARO-,MACD+,AO-,TRIX-,CHOPr,        -500.0
# 19         SMA-,CMO-,KVO+,EFI-,TSI-,ARO+,MACD-,AO-,TRIX-,        -500.0
# 25         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 41         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD+,AO-,TRIX-,        -500.0
# 118        SMA-,CMO-,KVO-,EFI-,TSI+,ARO-,MACD-,AO-,TRIX-,        -700.0
# 132        SMA-,CMO-,KVO-,EFI-,TSI-,ARO+,MACD-,AO-,TRIX-,        -700.0
# 52         SMA-,CMO-,KVO-,EFI-,TSI-,ARO+,MACD-,AO-,TRIX-,        -700.0
# 42         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -700.0
# 36         SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -700.0
# 116        SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 87         SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 78         SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 63         SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 59         SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 57         SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 22         SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 0          SMA-,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,        -900.0
# 108  SMA+,CMO-,KVO-,EFI-,TSI-,ARO-,MACD-,AO+,TRIX+,CHOPt,       -3000.0
# 91   SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,CHOPt,       -7000.0
# 90   SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,CHOPt,       -7000.0
# 89   SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,CHOPt,       -7000.0
# 14   SMA-,CMO-,KVO+,EFI-,TSI-,ARO-,MACD-,AO-,TRIX-,CHOPt,       -7000.0
