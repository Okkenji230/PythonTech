# %% [markdown]
# # K's Reversal Indicators のデモ

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import matplotlib.dates as mdates
from datetime import date, datetime, timedelta
import numpy as np
from pandas_datareader import data as pdr
import mplfinance as mpf
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 株価データの取得

# %%
# 通貨ペアはマネーパートナーズのメニューに出てくるもののみ
list_ticker = ['USDJPY=X', 'EURJPY=X', 'GBPJPY=X', 'AUDJPY=X', 'CADJPY=X', 'NZDJPY=X', 'MXNJPY=X', 'CHFJPY=X', 'NOKJPY=X',\
               'ZARJPY=X', 'TRYJPY=X', 'ILSJPY=X',\
               'EURUSD=X', 'GBPUSD=X', 'AUDUSD=X', 'NZDUSD=X', 'AUDNZD=X', 'EURGBP=X', 'GBPAUD=X']

# %%
# Define the stock symbol and timeframe
# 現保有銘柄
symbol = 'GBPAUD=X'
#symbol = '9984.T'
end_date = datetime.today()
start_date = end_date - timedelta(days=1095)
yf.pdr_override()
# yahooサイトからデータをダウンロード
data = pdr.get_data_yahoo(symbol, start_date, end_date)
data.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2024-07-22  1.93127  1.94689  1.93151  1.93127    1.93127       0
# 2024-07-23  1.94746  1.95236  1.94552  1.94746    1.94746       0
# 2024-07-24  1.95108  1.96007  1.95050  1.95108    1.95108       0
# 2024-07-25  1.96190  1.97605  1.96164  1.96190    1.96190       0
# 2024-07-26  1.96547  1.96664  1.96209  1.96209    1.96209       0

# %% [markdown]
# ## K's Reversal Indicator (I) 戦略の実装

# %% [raw]
# 出典：Try This Very Powerful Market Reversal Indicator (by Sofien Kaabar)
# https://medium.com/@kaabar-sofien/try-this-very-powerful-market-reversal-indicator-aaa6a61d86e6

# %%
def kr_1_strategy(data):
    kr_Buy = []
    kr_Sell = []
    bb = ta.bbands(data['Adj Close'], length=100, std=1.5)
    df = pd.concat([data, bb], axis=1).reindex(data.index)

    for i in range(0, len(df)):
        if df['Adj Close'][i] <= df['BBL_100_1.5'][i] and df['MACD_12_26_9'][i-1] <= df['MACDs_12_26_9'][i-1] \
           and df['MACD_12_26_9'][i] > df['MACDs_12_26_9'][i]:
            kr_Sell.append(np.nan)
            kr_Buy.append(df['Adj Close'][i])
        elif df['Adj Close'][i] >= df['BBU_100_1.5'][i] and df['MACD_12_26_9'][i-1] >= df['MACDs_12_26_9'][i-1] \
           and df['MACD_12_26_9'][i] < df['MACDs_12_26_9'][i]:
            kr_Buy.append(np.nan)
            kr_Sell.append(df['Adj Close'][i])        
        else:
            kr_Buy.append(np.nan)
            kr_Sell.append(np.nan)

    df['kr_Buy_Signal_price'] = kr_Buy
    df['kr_Sell_Signal_price'] = kr_Sell
    return df

# %%
df1 = data.copy()
# MACD, 同シグナル, 同ヒストグラムを計算し別データフレームに格納する
macd = ta.macd(df1['Close'])
# MACDの列を元のデータフレームに横連結する
df1 = pd.concat([df1, macd], axis=1).reindex(df1.index)
df1 = kr_1_strategy(df1)
df1
# Out:
#                Open     High      Low    Close  Adj Close  Volume  \
# Date
# 2021-07-27  1.87232  1.88613  1.87177  1.87180    1.87180       0
# 2021-07-28  1.88451  1.89210  1.88220  1.88441    1.88441       0
# 2021-07-29  1.88482  1.89318  1.88419  1.88480    1.88480       0
# 2021-07-30  1.88796  1.89708  1.88614  1.88787    1.88787       0
# 2021-08-02  1.89250  1.89478  1.88365  1.89250    1.89250       0
# ...             ...      ...      ...      ...        ...     ...
# 2024-07-22  1.93127  1.94689  1.93151  1.93127    1.93127       0
# 2024-07-23  1.94746  1.95236  1.94552  1.94746    1.94746       0
# 2024-07-24  1.95108  1.96007  1.95050  1.95108    1.95108       0
# 2024-07-25  1.96190  1.97605  1.96164  1.96190    1.96190       0
# 2024-07-26  1.96547  1.96664  1.96209  1.96209    1.96209       0
#
#             MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  BBL_100_1.5  \
# Date
# 2021-07-27           NaN            NaN            NaN          NaN
# 2021-07-28           NaN            NaN            NaN          NaN
# 2021-07-29           NaN            NaN            NaN          NaN
# 2021-07-30           NaN            NaN            NaN          NaN
# 2021-08-02           NaN            NaN            NaN          NaN
# ...                  ...            ...            ...          ...
# 2024-07-22      0.004656       0.003938       0.000718     1.896827
# 2024-07-23      0.006616       0.004718       0.001897     1.896712
# 2024-07-24      0.008364       0.005174       0.003191     1.896688
# 2024-07-25      0.010502       0.005849       0.004653     1.896448
# 2024-07-26      0.012073       0.005936       0.006137     1.895989
#
#             BBM_100_1.5  BBU_100_1.5  BBB_100_1.5  BBP_100_1.5  \
# Date
# 2021-07-27          NaN          NaN          NaN          NaN
# 2021-07-28          NaN          NaN          NaN          NaN
# 2021-07-29          NaN          NaN          NaN          NaN
# 2021-07-30          NaN          NaN          NaN          NaN
# 2021-08-02          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...
# 2024-07-22     1.919203     1.941578     2.331735     0.769658
# 2024-07-23     1.919284     1.941856     2.352163     1.124126
# 2024-07-24     1.919295     1.941902     2.355748     1.202989
# 2024-07-25     1.919382     1.942315     2.389697     1.426983
# 2024-07-26     1.919609     1.943230     2.461001     1.399218
#
#             kr_Buy_Signal_price  kr_Sell_Signal_price
# Date
# 2021-07-27                  NaN                   NaN
# 2021-07-28                  NaN                   NaN
# 2021-07-29                  NaN                   NaN
# 2021-07-30                  NaN                   NaN
# 2021-08-02                  NaN                   NaN
# ...                         ...                   ...
# 2024-07-22                  NaN                   NaN
# 2024-07-23                  NaN                   NaN
# 2024-07-24                  NaN                   NaN
# 2024-07-25                  NaN                   NaN
# 2024-07-26                  NaN                   NaN
#
# [783 rows x 16 columns]

# %% [markdown]
# ## K's Reversal Indicator (I) 戦略の図示

# %%
#plot
fig, ax1 = plt.subplots(figsize=(14,8))
fig.suptitle(symbol, fontsize=10, backgroundcolor='blue', color='white')
ax1 = plt.subplot2grid((14, 8), (0, 0), rowspan=8, colspan=14)
ax2 = plt.subplot2grid((14, 12), (10, 0), rowspan=6, colspan=14)
ax1.set_ylabel('Price')
ax1.plot(df1['Adj Close'],label='Close Price', linewidth=0.5, color='blue')
ax1.scatter(df1.index, df1['kr_Buy_Signal_price'], color='green', marker='^', alpha=1)
ax1.scatter(df1.index, df1['kr_Sell_Signal_price'], color='red', marker='v', alpha=1)
ax1.legend()
ax1.grid()
ax1.set_xlabel('Date', fontsize=8)

ax2.plot(df1['Adj Close'], label='Close', color='blue', alpha=0.35) #middle band
ax2.plot(df1['BBU_100_1.5'], label='Upper', color='green', alpha=0.35) #Upper band
ax2.plot(df1['BBL_100_1.5'], label='Lower', color='red', alpha=0.35) #lower band
ax2.fill_between(df1.index, df1['BBL_100_1.5'], df1['BBU_100_1.5'], alpha=0.1)
ax2.legend(loc='upper left')
ax2.grid()
plt.show()
# Out:
# C:\Users\nicjp\AppData\Local\Temp\ipykernel_13520\3806368944.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot2grid((14, 8), (0, 0), rowspan=8, colspan=14)

# %%
df1[['kr_Buy_Signal_price','kr_Sell_Signal_price']].tail(1)
# Out:
#             kr_Buy_Signal_price  kr_Sell_Signal_price
# Date
# 2024-07-26                  NaN                   NaN

# %% [markdown]
# ## K's Reversal Indicator (III) 戦略の実装

# %% [raw]
# Maximize Your Trading Potential Using This Powerful Indicator
# https://medium.com/@kaabar-sofien/maximize-your-trading-potential-using-this-powerful-indicator-c7a623b2cee4

# %%
def kr_3_strategy(df):
    kr_Buy = []
    kr_Sell = []
    df['return'] = df['Adj Close'].diff()
    df['rtcorr'] = df['return'].autocorr(lag=14)
    df['RSI'] = ta.rsi(df['Adj Close'], length=14)

    for i in range(0, len(df)):
        if df['rtcorr'][i] > 0.6 and df['RSI'][i] < 40:
            kr_Sell.append(np.nan)
            kr_Buy.append(df['Adj Close'][i])
        elif df['rtcorr'][i] > 0.6 and df['RSI'][i] > 60:
            kr_Buy.append(np.nan)
            kr_Sell.append(df['Adj Close'][i])        
        else:
            kr_Buy.append(np.nan)
            kr_Sell.append(np.nan)

    df['kr_Buy_Signal_price'] = kr_Buy
    df['kr_Sell_Signal_price'] = kr_Sell
    return df

# %%
df2 = data.copy()
df2 = kr_3_strategy(df2)
df2
# Out:
#                Open     High      Low    Close  Adj Close  Volume   return  \
# Date
# 2021-07-27  1.87232  1.88613  1.87177  1.87180    1.87180       0      NaN
# 2021-07-28  1.88451  1.89210  1.88220  1.88441    1.88441       0  0.01261
# 2021-07-29  1.88482  1.89318  1.88419  1.88480    1.88480       0  0.00039
# 2021-07-30  1.88796  1.89708  1.88614  1.88787    1.88787       0  0.00307
# 2021-08-02  1.89250  1.89478  1.88365  1.89250    1.89250       0  0.00463
# ...             ...      ...      ...      ...        ...     ...      ...
# 2024-07-22  1.93127  1.94689  1.93151  1.93127    1.93127       0  0.00001
# 2024-07-23  1.94746  1.95236  1.94552  1.94746    1.94746       0  0.01619
# 2024-07-24  1.95108  1.96007  1.95050  1.95108    1.95108       0  0.00362
# 2024-07-25  1.96190  1.97605  1.96164  1.96190    1.96190       0  0.01082
# 2024-07-26  1.96547  1.96664  1.96209  1.96209    1.96209       0  0.00019
#
#               rtcorr        RSI  kr_Buy_Signal_price  kr_Sell_Signal_price
# Date
# 2021-07-27 -0.078441        NaN                  NaN                   NaN
# 2021-07-28 -0.078441        NaN                  NaN                   NaN
# 2021-07-29 -0.078441        NaN                  NaN                   NaN
# 2021-07-30 -0.078441        NaN                  NaN                   NaN
# 2021-08-02 -0.078441        NaN                  NaN                   NaN
# ...              ...        ...                  ...                   ...
# 2024-07-22 -0.078441  66.082864                  NaN                   NaN
# 2024-07-23 -0.078441  73.876322                  NaN                   NaN
# 2024-07-24 -0.078441  75.245917                  NaN                   NaN
# 2024-07-25 -0.078441  78.820243                  NaN                   NaN
# 2024-07-26 -0.078441  78.877925                  NaN                   NaN
#
# [783 rows x 11 columns]
