# %% [markdown]
# # K's Reversal Indicators のデモ

# %%
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import matplotlib.dates as mdates
from datetime import date, datetime, timedelta
import numpy as np
from pandas_datareader import data as pdr
import mplfinance as mpf
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 株価データの取得

# %%
# Define the stock symbol and timeframe
# 現保有銘柄
symbol = 'AUDNZD=X'
#symbol = '9984.T'
end_date = datetime.today()
start_date = end_date - timedelta(days=1095)
yf.pdr_override()
# yahooサイトからデータをダウンロード
data = pdr.get_data_yahoo(symbol, start_date, end_date)
data.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2024-07-19  1.10945  1.11236  1.10894  1.10945    1.10945       0
# 2024-07-22  1.11150  1.11258  1.10920  1.11150    1.11150       0
# 2024-07-23  1.11065  1.11238  1.10940  1.11065    1.11065       0
# 2024-07-24  1.11066  1.11355  1.10910  1.11066    1.11066       0
# 2024-07-25  1.10948  1.11004  1.10331  1.10409    1.10409       0

# %% [markdown]
# ## K's Reversal Indicator (I) 戦略の実装

# %% [raw]
# 出典：Try This Very Powerful Market Reversal Indicator (by Sofien Kaabar)
# https://medium.com/@kaabar-sofien/try-this-very-powerful-market-reversal-indicator-aaa6a61d86e6

# %%
def kr_strategy(data):
    kr_Buy = []
    kr_Sell = []
    bb = ta.bbands(data['Adj Close'], length=100, std=1.5)
    df = pd.concat([data, bb], axis=1).reindex(data.index)

    for i in range(0, len(df)):
        if df['Adj Close'][i] <= df['BBL_100_1.5'][i] and df['MACD_12_26_9'][i-1] <= df['MACDs_12_26_9'][i-1] \
           and df['MACD_12_26_9'][i] > df['MACDs_12_26_9'][i]:
            kr_Sell.append(np.nan)
            kr_Buy.append(df['Adj Close'][i])
        elif df['Adj Close'][i] >= df['BBU_100_1.5'][i] and df['MACD_12_26_9'][i-1] >= df['MACDs_12_26_9'][i-1] \
           and df['MACD_12_26_9'][i] < df['MACDs_12_26_9'][i]:
            kr_Buy.append(np.nan)
            kr_Sell.append(df['Adj Close'][i])        
        else:
            kr_Buy.append(np.nan)
            kr_Sell.append(np.nan)

    df['kr_Buy_Signal_price'] = kr_Buy
    df['kr_Sell_Signal_price'] = kr_Sell
    return df

# %%
# MACD, 同シグナル, 同ヒストグラムを計算し別データフレームに格納する
macd = ta.macd(data['Close'])
# MACDの列を元のデータフレームに横連結する
data = pd.concat([data, macd], axis=1).reindex(data.index)
data = kr_strategy(data)
data
# Out:
#                Open      High      Low     Close  Adj Close  Volume  \
# Date
# 2021-07-26  1.05491  1.055780  1.05310  1.055012   1.055012       0
# 2021-07-27  1.05459  1.059646  1.05330  1.053700   1.053700       0
# 2021-07-28  1.05785  1.060060  1.05590  1.057870   1.057870       0
# 2021-07-29  1.05920  1.060280  1.05420  1.059824   1.059824       0
# 2021-07-30  1.05463  1.055810  1.05150  1.054970   1.054970       0
# ...             ...       ...      ...       ...        ...     ...
# 2024-07-19  1.10945  1.112360  1.10894  1.109450   1.109450       0
# 2024-07-22  1.11150  1.112580  1.10920  1.111500   1.111500       0
# 2024-07-23  1.11065  1.112380  1.10940  1.110650   1.110650       0
# 2024-07-24  1.11066  1.113550  1.10910  1.110660   1.110660       0
# 2024-07-25  1.10948  1.110040  1.10331  1.104090   1.104090       0
#
#             MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  BBL_100_1.5  \
# Date
# ...

# %% [markdown]
# ## K's Reversal Indicator 戦略の図示

# %%
#plot
fig, ax1 = plt.subplots(figsize=(14,8))
fig.suptitle(symbol, fontsize=10, backgroundcolor='blue', color='white')
ax1 = plt.subplot2grid((14, 8), (0, 0), rowspan=8, colspan=14)
ax2 = plt.subplot2grid((14, 12), (10, 0), rowspan=6, colspan=14)
ax1.set_ylabel('Price')
ax1.plot(data['Adj Close'],label='Close Price', linewidth=0.5, color='blue')
ax1.scatter(data.index, data['kr_Buy_Signal_price'], color='green', marker='^', alpha=1)
ax1.scatter(data.index, data['kr_Sell_Signal_price'], color='red', marker='v', alpha=1)
ax1.legend()
ax1.grid()
ax1.set_xlabel('Date', fontsize=8)

ax2.plot(data['Adj Close'], label='Close', color='blue', alpha=0.35) #middle band
ax2.plot(data['BBU_100_1.5'], label='Upper', color='green', alpha=0.35) #Upper band
ax2.plot(data['BBL_100_1.5'], label='Lower', color='red', alpha=0.35) #lower band
ax2.fill_between(data.index, data['BBL_100_1.5'], data['BBU_100_1.5'], alpha=0.1)
ax2.legend(loc='upper left')
ax2.grid()
plt.show()
# Out:
# C:\Users\nicjp\AppData\Local\Temp\ipykernel_15952\2551563335.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax1 = plt.subplot2grid((14, 8), (0, 0), rowspan=8, colspan=14)

# %%
data[['kr_Buy_Signal_price','kr_Sell_Signal_price']].tail(1)
# Out:
#             kr_Buy_Signal_price  kr_Sell_Signal_price
# Date
# 2024-07-25                  NaN                   NaN
