# %% [markdown]
# # 第10章 テーブル表示を見やすくしよう

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# ## 10.1 値によってスタイルを変えるには

# %%
# データの読み込み
df = pd.read_csv("score.csv")
df
# Out:
#     生徒ID  国語   数学  理科  社会
# 0  ST001  70   97  80  78
# 1  ST002  68   89  78  92
# 2  ST003  88   92  90  98
# 3  ST004  71  100  79  68
# 4  ST005  73   87  65  60

# %% [markdown]
# ### やってみよう

# %%
def style_low_score(x):
    style = "font-weight: bold;" if x < 70 else None
    return style

df.style.map(
    style_low_score, subset = ["国語","数学","理科","社会"]
)
# Out:
# <style type="text/css">
# #T_d52e5_row1_col1, #T_d52e5_row3_col4, #T_d52e5_row4_col3, #T_d52e5_row4_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d52e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d52e5_level0_col0" class="col_heading level0 col0" >生徒ID</th>
#       <th id="T_d52e5_level0_col1" class="col_heading level0 col1" >国語</th>
#       <th id="T_d52e5_level0_col2" class="col_heading level0 col2" >数学</th>
#       <th id="T_d52e5_level0_col3" class="col_heading level0 col3" >理科</th>
#       <th id="T_d52e5_level0_col4" class="col_heading level0 col4" >社会</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d52e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d52e5_row0_col0" class="data row0 col0" >ST001</td>
#       <td id="T_d52e5_row0_col1" class="data row0 col1" >70</td>
#       <td id="T_d52e5_row0_col2" class="data row0 col2" >97</td>
#       <td id="T_d52e5_row0_col3" class="data row0 col3" >80</td>
#       <td id="T_d52e5_row0_col4" class="data row0 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_d52e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d52e5_row1_col0" class="data row1 col0" >ST002</td>
#       <td id="T_d52e5_row1_col1" class="data row1 col1" >68</td>
#       <td id="T_d52e5_row1_col2" class="data row1 col2" >89</td>
#       <td id="T_d52e5_row1_col3" class="data row1 col3" >78</td>
#       <td id="T_d52e5_row1_col4" class="data row1 col4" >92</td>
#     </tr>
#     <tr>
#       <th id="T_d52e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d52e5_row2_col0" class="data row2 col0" >ST003</td>
#       <td id="T_d52e5_row2_col1" class="data row2 col1" >88</td>
#       <td id="T_d52e5_row2_col2" class="data row2 col2" >92</td>
#       <td id="T_d52e5_row2_col3" class="data row2 col3" >90</td>
#       <td id="T_d52e5_row2_col4" class="data row2 col4" >98</td>
#     </tr>
#     <tr>
#       <th id="T_d52e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d52e5_row3_col0" class="data row3 col0" >ST004</td>
#       <td id="T_d52e5_row3_col1" class="data row3 col1" >71</td>
#       <td id="T_d52e5_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_d52e5_row3_col3" class="data row3 col3" >79</td>
#       <td id="T_d52e5_row3_col4" class="data row3 col4" >68</td>
#     </tr>
#     <tr>
#       <th id="T_d52e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d52e5_row4_col0" class="data row4 col0" >ST005</td>
#       <td id="T_d52e5_row4_col1" class="data row4 col1" >73</td>
#       <td id="T_d52e5_row4_col2" class="data row4 col2" >87</td>
#       <td id="T_d52e5_row4_col3" class="data row4 col3" >65</td>
#       <td id="T_d52e5_row4_col4" class="data row4 col4" >60</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## 10.2 平均値未満の値のスタイルを変えるには

# %%
# データの読み込み
df = pd.read_csv("score.csv")
df
# Out:
#     生徒ID  国語   数学  理科  社会
# 0  ST001  70   97  80  78
# 1  ST002  68   89  78  92
# 2  ST003  88   92  90  98
# 3  ST004  71  100  79  68
# 4  ST005  73   87  65  60

# %%
# 各教科の平均点を計算
df.mean(numeric_only=True)
# Out:
# 国語    74.0
# 数学    93.0
# 理科    78.4
# 社会    79.2
# dtype: float64

# %% [markdown]
# ### やってみよう

# %%
def style_below_mean(column):
    return column.apply(
        lambda x: "background-color: gray;"
        if x < column.mean()
        else None
    )

df.style.apply(
    style_below_mean, subset= ["国語","数学","理科","社会"]
)
# Out:
# <style type="text/css">
# #T_4be8a_row0_col1, #T_4be8a_row0_col4, #T_4be8a_row1_col1, #T_4be8a_row1_col2, #T_4be8a_row1_col3, #T_4be8a_row2_col2, #T_4be8a_row3_col1, #T_4be8a_row3_col4, #T_4be8a_row4_col1, #T_4be8a_row4_col2, #T_4be8a_row4_col3, #T_4be8a_row4_col4 {
#   background-color: gray;
# }
# </style>
# <table id="T_4be8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4be8a_level0_col0" class="col_heading level0 col0" >生徒ID</th>
#       <th id="T_4be8a_level0_col1" class="col_heading level0 col1" >国語</th>
#       <th id="T_4be8a_level0_col2" class="col_heading level0 col2" >数学</th>
#       <th id="T_4be8a_level0_col3" class="col_heading level0 col3" >理科</th>
#       <th id="T_4be8a_level0_col4" class="col_heading level0 col4" >社会</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4be8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4be8a_row0_col0" class="data row0 col0" >ST001</td>
#       <td id="T_4be8a_row0_col1" class="data row0 col1" >70</td>
#       <td id="T_4be8a_row0_col2" class="data row0 col2" >97</td>
#       <td id="T_4be8a_row0_col3" class="data row0 col3" >80</td>
#       <td id="T_4be8a_row0_col4" class="data row0 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_4be8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4be8a_row1_col0" class="data row1 col0" >ST002</td>
#       <td id="T_4be8a_row1_col1" class="data row1 col1" >68</td>
#       <td id="T_4be8a_row1_col2" class="data row1 col2" >89</td>
#       <td id="T_4be8a_row1_col3" class="data row1 col3" >78</td>
#       <td id="T_4be8a_row1_col4" class="data row1 col4" >92</td>
#     </tr>
#     <tr>
#       <th id="T_4be8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4be8a_row2_col0" class="data row2 col0" >ST003</td>
#       <td id="T_4be8a_row2_col1" class="data row2 col1" >88</td>
#       <td id="T_4be8a_row2_col2" class="data row2 col2" >92</td>
#       <td id="T_4be8a_row2_col3" class="data row2 col3" >90</td>
#       <td id="T_4be8a_row2_col4" class="data row2 col4" >98</td>
#     </tr>
#     <tr>
#       <th id="T_4be8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4be8a_row3_col0" class="data row3 col0" >ST004</td>
#       <td id="T_4be8a_row3_col1" class="data row3 col1" >71</td>
#       <td id="T_4be8a_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_4be8a_row3_col3" class="data row3 col3" >79</td>
#       <td id="T_4be8a_row3_col4" class="data row3 col4" >68</td>
#     </tr>
#     <tr>
#       <th id="T_4be8a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4be8a_row4_col0" class="data row4 col0" >ST005</td>
#       <td id="T_4be8a_row4_col1" class="data row4 col1" >73</td>
#       <td id="T_4be8a_row4_col2" class="data row4 col2" >87</td>
#       <td id="T_4be8a_row4_col3" class="data row4 col3" >65</td>
#       <td id="T_4be8a_row4_col4" class="data row4 col4" >60</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## 10.3 値が大きいほど背景色を濃くするには

# %%
# データの読み込み
df = pd.read_csv("score.csv")
df
# Out:
#     生徒ID  国語   数学  理科  社会
# 0  ST001  70   97  80  78
# 1  ST002  68   89  78  92
# 2  ST003  88   92  90  98
# 3  ST004  71  100  79  68
# 4  ST005  73   87  65  60

# %% [markdown]
# ### やってみよう

# %%
df.style.background_gradient(
    subset= ["国語","数学","理科","社会"], vmin=50, vmax=100
)
# Out:
# <style type="text/css">
# #T_662d9_row0_col1 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_662d9_row0_col2 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_662d9_row0_col3 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_662d9_row0_col4, #T_662d9_row1_col3 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_662d9_row1_col1, #T_662d9_row3_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_662d9_row1_col2 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_662d9_row1_col4, #T_662d9_row2_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_662d9_row2_col1 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_662d9_row2_col3 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_662d9_row2_col4 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_662d9_row3_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_662d9_row3_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_662d9_row3_col3 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_662d9_row4_col1 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_662d9_row4_col2 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_662d9_row4_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_662d9_row4_col4 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# </style>
# <table id="T_662d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_662d9_level0_col0" class="col_heading level0 col0" >生徒ID</th>
#       <th id="T_662d9_level0_col1" class="col_heading level0 col1" >国語</th>
#       <th id="T_662d9_level0_col2" class="col_heading level0 col2" >数学</th>
#       <th id="T_662d9_level0_col3" class="col_heading level0 col3" >理科</th>
#       <th id="T_662d9_level0_col4" class="col_heading level0 col4" >社会</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_662d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_662d9_row0_col0" class="data row0 col0" >ST001</td>
#       <td id="T_662d9_row0_col1" class="data row0 col1" >70</td>
#       <td id="T_662d9_row0_col2" class="data row0 col2" >97</td>
#       <td id="T_662d9_row0_col3" class="data row0 col3" >80</td>
#       <td id="T_662d9_row0_col4" class="data row0 col4" >78</td>
#     </tr>
#     <tr>
#       <th id="T_662d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_662d9_row1_col0" class="data row1 col0" >ST002</td>
#       <td id="T_662d9_row1_col1" class="data row1 col1" >68</td>
#       <td id="T_662d9_row1_col2" class="data row1 col2" >89</td>
#       <td id="T_662d9_row1_col3" class="data row1 col3" >78</td>
#       <td id="T_662d9_row1_col4" class="data row1 col4" >92</td>
#     </tr>
#     <tr>
#       <th id="T_662d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_662d9_row2_col0" class="data row2 col0" >ST003</td>
#       <td id="T_662d9_row2_col1" class="data row2 col1" >88</td>
#       <td id="T_662d9_row2_col2" class="data row2 col2" >92</td>
#       <td id="T_662d9_row2_col3" class="data row2 col3" >90</td>
#       <td id="T_662d9_row2_col4" class="data row2 col4" >98</td>
#     </tr>
#     <tr>
#       <th id="T_662d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_662d9_row3_col0" class="data row3 col0" >ST004</td>
#       <td id="T_662d9_row3_col1" class="data row3 col1" >71</td>
#       <td id="T_662d9_row3_col2" class="data row3 col2" >100</td>
#       <td id="T_662d9_row3_col3" class="data row3 col3" >79</td>
#       <td id="T_662d9_row3_col4" class="data row3 col4" >68</td>
#     </tr>
#     <tr>
#       <th id="T_662d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_662d9_row4_col0" class="data row4 col0" >ST005</td>
#       <td id="T_662d9_row4_col1" class="data row4 col1" >73</td>
#       <td id="T_662d9_row4_col2" class="data row4 col2" >87</td>
#       <td id="T_662d9_row4_col3" class="data row4 col3" >65</td>
#       <td id="T_662d9_row4_col4" class="data row4 col4" >60</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## 10.4 Jupyterのセルの途中でDataFrameを表示するには

# %%
# データの読み込み
df = pd.read_csv("score.csv")
df
# Out:
#     生徒ID  国語   数学  理科  社会
# 0  ST001  70   97  80  78
# 1  ST002  68   89  78  92
# 2  ST003  88   92  90  98
# 3  ST004  71  100  79  68
# 4  ST005  73   87  65  60

# %%
for column in ["国語", "数学", "理科", "社会"]:
    filtered_df = df[df[column] >= 90]
    print(f"==={column}が90点以上の生徒のデータ===")
    print(filtered_df)  # 90点以上の生徒のデータを表示

# %% [markdown]
# ### やってみよう

# %%
for column in ["国語", "数学", "理科", "社会"]:
    filtered_df = df[df[column] >= 90]
    print(f"==={column}が90点以上の生徒のデータ===")
    display(filtered_df)
# Out:
# ===国語が90点以上の生徒のデータ===
# Empty DataFrame
# Columns: [生徒ID, 国語, 数学, 理科, 社会]
# Index: []
# ===数学が90点以上の生徒のデータ===
#     生徒ID  国語   数学  理科  社会
# 0  ST001  70   97  80  78
# 2  ST003  88   92  90  98
# 3  ST004  71  100  79  68
# ===理科が90点以上の生徒のデータ===
#     生徒ID  国語  数学  理科  社会
# 2  ST003  88  92  90  98
# ===社会が90点以上の生徒のデータ===
#     生徒ID  国語  数学  理科  社会
# 1  ST002  68  89  78  92
# 2  ST003  88  92  90  98

# %% [markdown]
# ---

# %% [markdown]
# ## 10.5 pandasの行を省略させずに表示するには

# %%
# データの読み込み
df = pd.read_csv("score_long.csv")
df
# Out:
#      生徒ID  国語   数学  理科  社会
# 0   ST001  70   97  80  78
# 1   ST002  68   89  78  92
# 2   ST003  88   92  90  98
# 3   ST004  71  100  79  68
# 4   ST005  73   87  65  60
# ..    ...  ..  ...  ..  ..
# 95  ST095  88   78  85  91
# 96  ST096  81   98  92  88
# 97  ST097  83   83  88  78
# 98  ST098  78   83  84  75
# 99  ST099  89  100  89  79
#
# [100 rows x 5 columns]

# %% [markdown]
# ### やってみよう

# %% [markdown]
# ---

# %% [markdown]
# ## 10.6 数値の書式を指定するには

# %%
# データの読み込み
df = pd.read_csv("ctr.csv")
df
# Out:
#          月   表示数  クリック数     クリック率  クリック数の変化率
# 0  2022-01  2010    162  0.080597        NaN
# 1  2022-02  2140    158  0.073832  -0.024691
# 2  2022-03  2429    198  0.081515   0.253165
# 3  2022-04  2340    198  0.084615   0.000000

# %% [markdown]
# ### やってみよう

# %%
df.style.format(precision=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ccbf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccbf1_level0_col0" class="col_heading level0 col0" >月</th>
#       <th id="T_ccbf1_level0_col1" class="col_heading level0 col1" >表示数</th>
#       <th id="T_ccbf1_level0_col2" class="col_heading level0 col2" >クリック数</th>
#       <th id="T_ccbf1_level0_col3" class="col_heading level0 col3" >クリック率</th>
#       <th id="T_ccbf1_level0_col4" class="col_heading level0 col4" >クリック数の変化率</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccbf1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ccbf1_row0_col0" class="data row0 col0" >2022-01</td>
#       <td id="T_ccbf1_row0_col1" class="data row0 col1" >2010</td>
#       <td id="T_ccbf1_row0_col2" class="data row0 col2" >162</td>
#       <td id="T_ccbf1_row0_col3" class="data row0 col3" >0.081</td>
#       <td id="T_ccbf1_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ccbf1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ccbf1_row1_col0" class="data row1 col0" >2022-02</td>
#       <td id="T_ccbf1_row1_col1" class="data row1 col1" >2140</td>
#       <td id="T_ccbf1_row1_col2" class="data row1 col2" >158</td>
#       <td id="T_ccbf1_row1_col3" class="data row1 col3" >0.074</td>
#       <td id="T_ccbf1_row1_col4" class="data row1 col4" >-0.025</td>
#     </tr>
#     <tr>
#       <th id="T_ccbf1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ccbf1_row2_col0" class="data row2 col0" >2022-03</td>
#       <td id="T_ccbf1_row2_col1" class="data row2 col1" >2429</td>
#       <td id="T_ccbf1_row2_col2" class="data row2 col2" >198</td>
#       <td id="T_ccbf1_row2_col3" class="data row2 col3" >0.082</td>
#       <td id="T_ccbf1_row2_col4" class="data row2 col4" >0.253</td>
#     </tr>
#     <tr>
#       <th id="T_ccbf1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ccbf1_row3_col0" class="data row3 col0" >2022-04</td>
#       <td id="T_ccbf1_row3_col1" class="data row3 col1" >2340</td>
#       <td id="T_ccbf1_row3_col2" class="data row3 col2" >198</td>
#       <td id="T_ccbf1_row3_col3" class="data row3 col3" >0.085</td>
#       <td id="T_ccbf1_row3_col4" class="data row3 col4" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---

# %% [markdown]
# ## 10.7 複数のスタイルを適用するには

# %%
# データの読み込み
df = pd.read_csv("ctr.csv", index_col="月")
df
# Out:
#           表示数  クリック数     クリック率  クリック数の変化率
# 月
# 2022-01  2010    162  0.080597        NaN
# 2022-02  2140    158  0.073832  -0.024691
# 2022-03  2429    198  0.081515   0.253165
# 2022-04  2340    198  0.084615   0.000000

# %% [markdown]
# ### やってみよう

# %%
def apply_style(styler):
    # 小数点以下2ケタパーセント欠測-表示
    styler.format(
        "{:.2%}", subset=["クリック率","クリック数の変化率"], na_rep="-"
    )
    # 各列の最大値の背景色を薄灰色に
    styler.highlight_max(
        subset=["表示数","クリック数","クリック率"], color="lightgray"
    )
    # 負の値の背景色を赤に
    styler.highlight_between(
        subset=["クリック数の変化率"],
        color="red",
        right=0,
        inclusive="neither",
    )
    return styler

# スタイルを一括で運用
df.style.pipe(apply_style)
# Out:
# <style type="text/css">
# #T_7adb8_row1_col3 {
#   background-color: red;
# }
# #T_7adb8_row2_col0, #T_7adb8_row2_col1, #T_7adb8_row3_col1, #T_7adb8_row3_col2 {
#   background-color: lightgray;
# }
# </style>
# <table id="T_7adb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7adb8_level0_col0" class="col_heading level0 col0" >表示数</th>
#       <th id="T_7adb8_level0_col1" class="col_heading level0 col1" >クリック数</th>
#       <th id="T_7adb8_level0_col2" class="col_heading level0 col2" >クリック率</th>
#       <th id="T_7adb8_level0_col3" class="col_heading level0 col3" >クリック数の変化率</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >月</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7adb8_level0_row0" class="row_heading level0 row0" >2022-01</th>
#       <td id="T_7adb8_row0_col0" class="data row0 col0" >2010</td>
#       <td id="T_7adb8_row0_col1" class="data row0 col1" >162</td>
#       <td id="T_7adb8_row0_col2" class="data row0 col2" >8.06%</td>
#       <td id="T_7adb8_row0_col3" class="data row0 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_7adb8_level0_row1" class="row_heading level0 row1" >2022-02</th>
#       <td id="T_7adb8_row1_col0" class="data row1 col0" >2140</td>
#       <td id="T_7adb8_row1_col1" class="data row1 col1" >158</td>
#       <td id="T_7adb8_row1_col2" class="data row1 col2" >7.38%</td>
#       <td id="T_7adb8_row1_col3" class="data row1 col3" >-2.47%</td>
#     </tr>
#     <tr>
#       <th id="T_7adb8_level0_row2" class="row_heading level0 row2" >2022-03</th>
#       <td id="T_7adb8_row2_col0" class="data row2 col0" >2429</td>
#       <td id="T_7adb8_row2_col1" class="data row2 col1" >198</td>
#       <td id="T_7adb8_row2_col2" class="data row2 col2" >8.15%</td>
#       <td id="T_7adb8_row2_col3" class="data row2 col3" >25.32%</td>
#     </tr>
#     <tr>
#       <th id="T_7adb8_level0_row3" class="row_heading level0 row3" >2022-04</th>
#       <td id="T_7adb8_row3_col0" class="data row3 col0" >2340</td>
#       <td id="T_7adb8_row3_col1" class="data row3 col1" >198</td>
#       <td id="T_7adb8_row3_col2" class="data row3 col2" >8.46%</td>
#       <td id="T_7adb8_row3_col3" class="data row3 col3" >0.00%</td>
#     </tr>
#   </tbody>
# </table>
