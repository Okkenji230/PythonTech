# %% [markdown]
# # yfinanceによる株価データ獲得のテスト

# %%
import yfinance as yf;print(yf.__version__)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date, datetime, timedelta
# Out:
# 0.2.54

# %%
ticker = '7203.T'
df = yf.download(ticker, start='2020-01-01', end='2024-12-06')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df.tail()
# Out:
# Price        Close    High     Low    Open    Volume
# Ticker      7203.T  7203.T  7203.T  7203.T    7203.T
# Date
# 2024-11-29  2551.5  2618.0  2546.5  2612.0  24496900
# 2024-12-02  2611.0  2620.5  2557.0  2565.0  20253600
# 2024-12-03  2652.0  2665.0  2604.0  2611.0  28572300
# 2024-12-04  2631.0  2657.5  2611.5  2634.5  19005600
# 2024-12-05  2632.0  2649.5  2613.0  2649.0  20694400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1205 entries, 2020-01-06 to 2024-12-05
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Close, 7203.T)   1205 non-null   float64
#  1   (High, 7203.T)    1205 non-null   float64
#  2   (Low, 7203.T)     1205 non-null   float64
#  3   (Open, 7203.T)    1205 non-null   float64
#  4   (Volume, 7203.T)  1205 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 56.5 KB

# %%
df1 = df.reset_index()
df1.head()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker                  7203.T       7203.T       7203.T       7203.T
# 0      2020-01-06  1331.830078  1342.569181  1325.668273  1337.815874
# 1      2020-01-07  1358.237793  1359.470175  1341.336886  1347.498691
# 2      2020-01-08  1340.984863  1345.386153  1327.604879  1331.830160
# 3      2020-01-09  1350.315430  1353.836461  1344.681758  1350.667554
# 4      2020-01-10  1348.730835  1355.244764  1346.970320  1354.716630
#
# Price     Volume
# Ticker    7203.T
# 0       33361500
# 1       24803500
# 2       28061000
# 3       21265000
# 4       17417000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Date, )          1205 non-null   datetime64[ns]
#  1   (Close, 7203.T)   1205 non-null   float64
#  2   (High, 7203.T)    1205 non-null   float64
#  3   (Low, 7203.T)     1205 non-null   float64
#  4   (Open, 7203.T)    1205 non-null   float64
#  5   (Volume, 7203.T)  1205 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 56.6 KB

# %%
df2 = df.copy()
df2.columns = [col[0] if isinstance(col, tuple) else col for col in df2.columns]
df2.head()
# Out:
#                   Close         High          Low         Open    Volume
# Date
# 2020-01-06  1331.830078  1342.569181  1325.668273  1337.815874  33361500
# 2020-01-07  1358.237793  1359.470175  1341.336886  1347.498691  24803500
# 2020-01-08  1340.984863  1345.386153  1327.604879  1331.830160  28061000
# 2020-01-09  1350.315430  1353.836461  1344.681758  1350.667554  21265000
# 2020-01-10  1348.730835  1355.244764  1346.970320  1354.716630  17417000

# %%
pair = 'USDJPY=X'
#end = datetime.datetime.now(datetime.UTC)  #標準時が必要な場合
end = datetime.now()
start = end - timedelta(days=7)
end_date = end.strftime('%Y-%m-%d')
start_date = start.strftime('%Y-%m-%d')
data1 = yf.download(pair, start=start_date, end=end_date, interval="1m", period="1d")
data1.columns = [col[0] if isinstance(col, tuple) else col for col in data1.columns]
data2 = yf.download(pair, interval="1m", period="1d")
data2.columns = [col[0] if isinstance(col, tuple) else col for col in data2.columns]
data = pd.concat([data1,data2])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
